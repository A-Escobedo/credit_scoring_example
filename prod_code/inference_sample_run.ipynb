# %%
from sklearn.metrics import confusion_matrix, make_scorer
# Define a function to calculate specificity
def specificity(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    specificity = tn / (tn+fp)
    return specificity

# Make a scorer from the custom specificity function
specificity_scorer = make_scorer(specificity, greater_is_better=True)

# %%
# Import libraries
from Cleanning import general_info, internal_payments, credit_reports
from Featurizing import get_features
from Inference import get_prediction
# Out:
# c:\Users\AldoErnestoEscobedoT\OneDrive - Freedom to Scale SA de CV\Documentos\challenge\classification_model\Inference.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = X[col].astype('category')
# c:\Users\AldoErnestoEscobedoT\anaconda3\lib\site-packages\sklearn\utils\validation.py:623: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Users\AldoErnestoEscobedoT\anaconda3\lib\site-packages\sklearn\utils\validation.py:623: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# ...

# %%
# Get current features
current_features = get_features(general_info_df=general_info, internal_payments=internal_payments, credit_reports=credit_reports).sort_values(by=["user_id","limit_date"], ascending=True).drop_duplicates("user_id", keep="last")
current_features.head(20)
# Out:
#      application_id     application_date   documentation_date  user_id  \
# 699               1  2018-04-23 00:00:00  2018-04-30 16:25:18   1000.0
# 869               2  2018-07-31 15:33:05  2018-08-22 16:25:25   1001.0
# 163               3  2018-08-03 11:00:10  2018-08-13 12:53:33   1002.0
# 121               4  2018-09-12 18:51:52  2018-09-19 12:11:39   1003.0
# 697               5  2018-09-17 14:11:45  2018-09-26 16:21:22   1004.0
# 918               6  2018-09-18 00:00:00  2018-09-19 15:35:59   1005.0
# 481               7  2018-09-19 16:51:21  2018-10-02 18:46:08   1006.0
# 248            1073  2021-02-22 17:05:06  2021-02-23 20:19:06   1007.0
# 858             295  2019-07-09 00:00:00  2019-07-19 11:35:57   1008.0
# 899             338  2019-08-08 00:00:00  2019-08-09 13:41:03   1009.0
# 703              11  2018-10-05 12:49:10  2018-10-08 15:01:22   1010.0
# 889             287  2019-07-03 00:00:00  2019-07-04 18:27:13   1011.0
# ...

# %%
# Calculate Scores
current_features["score"]=get_prediction(features_df=current_features)
# Out:
# c:\Users\AldoErnestoEscobedoT\OneDrive - Freedom to Scale SA de CV\Documentos\challenge\classification_model\Inference.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# c:\Users\AldoErnestoEscobedoT\anaconda3\lib\site-packages\sklearn\utils\validation.py:623: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Users\AldoErnestoEscobedoT\anaconda3\lib\site-packages\sklearn\utils\validation.py:623: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# ...

# %%
# Select top 20 clients to offer better loans
current_features.sort_values("score", ascending=False)[["user_id", "score"]].head(20)
# Out:
#      user_id     score
# 102   1023.0  0.956492
# 593   1145.0  0.947264
# 694   1857.0  0.946858
# 500   1242.0  0.942399
# 98    1248.0  0.931740
# 699   1000.0  0.926190
# 86    1184.0  0.906029
# 96    1120.0  0.902632
# 328   1178.0  0.901023
# 468   1017.0  0.883459
# 540   1087.0  0.876917
# 625   1683.0  0.867271
# 154   1037.0  0.863102
# 570   1440.0  0.855275
# 649   1851.0  0.843440
# 631   1657.0  0.842126
# 545   1231.0  0.842095
# 180   1318.0  0.834156
# 23    1123.0  0.833932
# 393   1032.0  0.832180
